# %% [markdown]
# # Using DataFrames with RLM
#
# This tutorial shows how to pass pandas DataFrames to DSPy's RLM (Recursive Language Model) module while preserving data types.

# %% [markdown]
# ## Setup
#
# First, install the required packages:

# %%
# %pip install -q dspy 
# %pip install -q pandas

# %%
import dspy
import pandas as pd

# Configure your LM
lm = dspy.LM("openai/gpt-4.1-mini")
dspy.configure(lm=lm)

# %% [markdown]
# ## Create Sample Data
#
# Let's create a DataFrame with various data types to demonstrate type preservation:

# %%
sales_data = pd.DataFrame({
    'date': pd.to_datetime(['2024-01-15', '2024-01-16', '2024-01-17', '2024-01-18', '2024-01-19']),
    'product': pd.Categorical(['Widget', 'Gadget', 'Widget', 'Gizmo', 'Gadget']),
    'quantity': [10, 25, 15, 8, 30],
    'price': [29.99, 49.99, 29.99, 99.99, 49.99],
    'is_promotion': [True, False, True, False, True]
})

print("DataFrame:")
print(sales_data)
print("\nData types:")
print(sales_data.dtypes)
# Out:
# DataFrame:
#         date product  quantity  price  is_promotion
# 0 2024-01-15  Widget        10  29.99          True
# 1 2024-01-16  Gadget        25  49.99         False
# 2 2024-01-17  Widget        15  29.99          True
# 3 2024-01-18   Gizmo         8  99.99         False
# 4 2024-01-19  Gadget        30  49.99          True
#
# Data types:
# date            datetime64[us]
# product               category
# quantity                 int64
# price                  float64
# is_promotion              bool
# dtype: object

# %% [markdown]
# ## Define a Signature with DataFrame
#
# Use `dspy.DataFrame` as an input field type. RLM will have full access to the data:

# %%
class AnalyzeSales(dspy.Signature):
    """Analyze sales data and provide insights."""
    
    data: dspy.DataFrame = dspy.InputField(desc="Sales transaction data")
    total_revenue: float = dspy.OutputField(desc="Total revenue across all sales")
    top_product: str = dspy.OutputField(desc="Product with highest quantity sold")
    summary: str = dspy.OutputField(desc="Brief analysis summary")

# %% [markdown]
# ## Run with RLM
#
# RLM executes Python code in a sandbox where the DataFrame is available with all its types preserved:

# %%
analyzer = dspy.RLM(AnalyzeSales, verbose=True)
result = analyzer(data=sales_data)
# Out:
# 2026/02/09 21:31:56 INFO dspy.predict.rlm: RLM iteration 1/20
# Reasoning: I have a sales transaction DataFrame named `data` with columns: date, product, quantity, price, and is_promotion. The goal is to analyze this data to provide three outputs: total revenue (as a float), top product by revenue, and a summary.
#
# First, I will explore the data by printing its structure and a few rows to confirm the contents and understand the data types. Then, I will calculate the total revenue as quantity * price summed over all rows. Next, I will determine the top product by total revenue and also generate a brief summary describing insights from the data.
#
# My initial step is to print a preview of the data and some basic information about the DataFrame.
# Code:
# print(data.info())
# print(data.head())
# 2026/02/09 21:32:00 INFO dspy.predict.rlm: RLM iteration 2/20
# Reasoning: I have confirmed the data structure and types. The 'date' column is datetime, 'product' and 'is_promotion' are categorical (though currently object and bool), 'quantity' is int, and 'price' is float. I see 5 transactions for three products (Widget, Gadget, Gizmo).
#
# Next, I will:
# 1. Calculate total revenue by summing quantity * price across all rows.
# 2. Calculate revenue per product and identify the product with the highest revenue.
# 3. Prepare a summary that includes key points like total revenue, top product, and maybe promotion impact or date range.
#
# I will implement step 1 and 2 now and print the intermediate results for verification.
# Code:
# ```python
# # Calculate revenue per row
# data['revenue'] = data['quantity'] * data['price']
#
# # Total revenue
# total_revenue = data['revenue'].sum()
#
# # Revenue grouped by product
# product_revenue = data.groupby('product')['revenue'].sum()
#
# # Identify product with highest revenue
# top_product = product_revenue.idxmax()
#
# print(f"Total Revenue: {total_revenue}")
# print(f"Revenue by Product:\n{product_revenue}")
# print(f"Top Product: {top_product}")
# ```
# 2026/02/09 21:32:00 INFO dspy.predict.rlm: RLM iteration 3/20
# Reasoning: I have calculated the total revenue as 4299.12 and found that the top product by revenue is "Gadget". The revenue by product distribution shows "Gadget" leading, followed by "Gizmo" and "Widget".
#
# Now I need to generate a concise summary of these insights. The summary will mention the total revenue, highlight the top-performing product, and optionally provide additional insights such as the impact of promotions or the date range covered by the data.
#
# I will check the range of dates in the data and briefly examine promotion impact on revenue before composing the summary.
# Code:
# ```python
# # Extract date range
# date_range = (data['date'].min(), data['date'].max())
#
# # Calculate total revenue during promotion and not during promotion
# promo_revenue = data.loc[data['is_promotion'], 'revenue'].sum()
# non_promo_revenue = data.loc[~data['is_promotion'], 'revenue'].sum()
#
# # Compose summary
# summary = (
#     f"The sales data covers the period from {date_range[0].strftime('%Y-%m-%d')} "
#     f"to {date_range[1].strftime('%Y-%m-%d')}. Total revenue generated is ${total_revenue:.2f}. "
#     f"The top product by revenue is '{top_product}', contributing ${product_revenue[top_product]:.2f}. "
#     f"Revenue from promotional sales is ${promo_revenue:.2f}, "
#     f"while non-promotional sales account for ${non_promo_revenue:.2f}."
# )
#
# print(summary)
# ```
# 2026/02/09 21:32:00 INFO dspy.predict.rlm: RLM iteration 4/20
# Reasoning: The error indicates a KeyError for the 'revenue' column. This means the 'revenue' column added in Step 2 possibly isn't carried over in the current environment or the operation creating it did not persist. To proceed, I need to ensure the 'revenue' column is present before calculating the promo and non-promo revenues and the date range. I will re-add the 'revenue' column and continue from there.
# Code:
# # Recalculate revenue column to ensure presence
# data['revenue'] = data['quantity'] * data['price']
#
# # Extract date range
# date_range = (data['date'].min(), data['date'].max())
#
# # Calculate total revenue during promotion and not during promotion
# promo_revenue = data.loc[data['is_promotion'], 'revenue'].sum()
# non_promo_revenue = data.loc[~data['is_promotion'], 'revenue'].sum()
#
# # Recalculate total and product revenue in case needed
# total_revenue = data['revenue'].sum()
# product_revenue = data.groupby('product')['revenue'].sum()
# top_product = product_revenue.idxmax()
#
# # Compose summary
# summary = (
#     f"The sales data covers the period from {date_range[0].strftime('%Y-%m-%d')} "
#     f"to {date_range[1].strftime('%Y-%m-%d')}. Total revenue generated is ${total_revenue:.2f}. "
#     f"The top product by revenue is '{top_product}', contributing ${product_revenue[top_product]:.2f}. "
#     f"Revenue from promotional sales is ${promo_revenue:.2f}, "
#     f"while non-promotional sales account for ${non_promo_revenue:.2f}."
# )
#
# print(summary)
# 2026/02/09 21:32:00 INFO dspy.predict.rlm: RLM iteration 5/20
# Reasoning: The error indicates that the 'date' column in the data is currently of type string (object) rather than datetime, so calling .strftime on it fails. Although in the initial info print it appeared to be datetime64, in the executed environment it may have been converted to string or not properly parsed.
#
# To fix this, I need to ensure the 'date' column is converted to pandas datetime type before extracting the min/max dates and using .strftime. I will convert the 'date' column to datetime, then proceed to extract date range, calculate revenues, and print the summary.
# Code:
# ```python
# import pandas as pd
#
# # Ensure 'date' is datetime type
# data['date'] = pd.to_datetime(data['date'])
#
# # Recalculate revenue column to ensure presence
# data['revenue'] = data['quantity'] * data['price']
#
# # Extract date range
# date_range = (data['date'].min(), data['date'].max())
#
# # Calculate total revenue during promotion and not during promotion
# promo_revenue = data.loc[data['is_promotion'], 'revenue'].sum()
# non_promo_revenue = data.loc[~data['is_promotion'], 'revenue'].sum()
#
# # Recalculate total and product revenue
# total_revenue = data['revenue'].sum()
# product_revenue = data.groupby('product')['revenue'].sum()
# top_product = product_revenue.idxmax()
#
# # Compose summary
# summary = (
#     f"The sales data covers the period from {date_range[0].strftime('%Y-%m-%d')} "
#     f"to {date_range[1].strftime('%Y-%m-%d')}. Total revenue generated is ${total_revenue:.2f}. "
#     f"The top product by revenue is '{top_product}', contributing ${product_revenue[top_product]:.2f}. "
#     f"Revenue from promotional sales is ${promo_revenue:.2f}, "
#     f"while non-promotional sales account for ${non_promo_revenue:.2f}."
# )
#
# print(summary)
# ```
# 2026/02/09 21:32:00 INFO dspy.predict.rlm: RLM iteration 6/20
# Reasoning: I have successfully calculated and summarized the key sales insights.
# - Total revenue is $4299.12.
# - The top revenue-generating product is "Gadget" with $2749.45.
# - The data spans from 2024-01-15 to 2024-01-19.
# - Promotional sales generated $2249.45, and non-promotional sales generated $2049.67.
#
# These values satisfy all the requested outputs:
# - total_revenue as a single float,
# - top_product as string,
# - a summary string with overall insights.
#
# I am ready to submit these results.
# Code:
# SUBMIT(total_revenue, top_product, summary)

# %%
print(f"Total Revenue: ${result.total_revenue:.2f}")
print(f"Top Product: {result.top_product}")
print(f"Summary: {result.summary}")
# Out:
# Total Revenue: $4299.12
# Top Product: Gadget
# Summary: The sales data covers the period from 2024-01-15 to 2024-01-19. Total revenue generated is $4299.12. The top product by revenue is 'Gadget', contributing $2749.45. Revenue from promotional sales is $2249.45, while non-promotional sales account for $2049.67.

# %% [markdown]
# ## How It Works
#
# Behind the scenes:
#
# 1. **Wrapping**: RLM auto-wraps raw pandas DataFrames into `dspy.DataFrame` when the signature field declares that type
# 2. **Serialization**: The DataFrame is serialized to JSON records via `pandas.to_json()`
# 3. **Injection**: The JSON is written into the Pyodide sandbox's virtual filesystem
# 4. **Reconstruction**: RLM generates and runs Python code that reads the JSON back into a pandas DataFrame
#
# Note: Since data passes through JSON, some dtypes may need re-inference on the sandbox side (e.g., dates arrive as strings). The LLM typically handles this as part of its analysis code.
#
# The LLM sees a structured preview of the data in the prompt:

# %%
# See what the LLM sees
df_wrapped = dspy.DataFrame(sales_data)
print(df_wrapped.rlm_preview())
# Out:
# DataFrame: 5 rows x 5 columns
#
# Columns:
#   date: datetime64[us]
#   product: category
#   quantity: int64
#   price: float64
#   is_promotion: bool
#
# Sample (first 3 rows):
#         date product  quantity  price  is_promotion
# 0 2024-01-15  Widget        10  29.99          True
# 1 2024-01-16  Gadget        25  49.99         False
# 2 2024-01-17  Widget        15  29.99          True
